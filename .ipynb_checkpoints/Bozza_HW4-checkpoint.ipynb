# %%
import json
json_data = open('/home/mattiapdo/Desktop/ADM - Algorithmic Methods/Homework_3/reduced_dblp.json').read()

# %%
data = json.loads(json_data)

# %% [markdown]
# data is a list of dictionaries... let's see the first item

# %%
data[100]
# Out:
# {'authors': [{'author': 'kaustubh beedkar', 'author_id': 85911},
#   {'author': 'rainer gemulla', 'author_id': 272064}],
#  'id_conference': 'conf/sigmod/2015',
#  'id_conference_int': 3345,
#  'id_publication': 'conf/sigmod/beedkarg15',
#  'id_publication_int': 175561,
#  'title': 'lash: large-scale sequence mining with hierarchies.'}

# %% [markdown]
# so... for each publication we are interested in
# - the title (?)                      -->
#                                              data[i]['title']
# - the conference                     -->
#                                              data[i]['id_conference_int']
# - the id_publication_int             -->
#                                              data[i]['id_publication_int']
# - the dictionary of the authors      -->
#                                          data[i]['authors'][j]['author'] or
#                                          data[i]['authors'][j]['author_id']  ... for j in [0 , num of authors]

# %% [markdown]
# We want to create a graph of all the authors... so we can scroll the list and, for each element of the list, check whether each author is in a dictionary 'of all the authors', that is something like:
#
#     {'author': 'pippo' , 'publications': [first_pippo's_publication_id, second_pippo's_publication_id, ...],
#       'author': 'mickey' , 'publications': [first_mickey's_publication_id, second_mickey's_publication_id, ...], ... }
#
# If NO
# - add the author to the dictionary, and it's corresponding value: the id of the current publication
# - create a new vertex in the graph, named as the id of the author
#
# If YES
# - insert the current publication id to the author in the dictionary
#
# Before moving to next item of the list (to another publication), let's add a link between the authors that collaborated for that work (if they are not linked yet)

# %%
#code
import networkx as nx
import matplotlib as plt

# %%
def nodes_connected(G, u, v):
    return u in G.neighbors(v) and v in G.neighbors(u)

# %%
Authors = nx.Graph()
Authors.name = 'Authors Graph'

inverted_dictionary = {}
for dictionary in data:
    # add authors to the graph if they are not in and
    # build the inverted dictionary
    for author in dictionary['authors']:
        if author['author_id'] not in inverted_dictionary:
            Authors.add_node(author['author_id'], name = author['author'] )
            inverted_dictionary[author['author_id']] = {'name': author['author'], 'publications':[(dictionary['id_publication_int'],dictionary['title'])]}
        else:
            inverted_dictionary[author['author_id']]['publications'].append((dictionary['id_publication_int'],dictionary['title']))
    
    # add edges between authors that appear as contributors in the publication
    # if they are not still connected
    for author1 in dictionary['authors']:
        for author2 in dictionary['authors']:
            if not nodes_connected(Authors, author1['author_id'], author2['author_id']) and author1!=author2:
                Authors.add_edge(author1['author_id'],author2['author_id'])

# %%
inverted_dictionary
# Out:
# {255206: {'name': 'h&eacute;lio marcos paz de almeida',
#   'publications': [(161535,
#     'is there a best quality metric for graph clusters?')]},
#  255207: {'name': 'dorgival olavo guedes neto',
#   'publications': [(161535,
#     'is there a best quality metric for graph clusters?')]},
#  16585: {'name': 'wagner meira jr.',
#   'publications': [(161535,
#     'is there a best quality metric for graph clusters?')]},
#  255208: {'name': 'mohammed j. zaki',
#   'publications': [(161535,
#     'is there a best quality metric for graph clusters?')]},
#  255280: {'name': 'beno&icirc;t fr&eacute;nay',
#   'publications': [(161584,
#     'label noise-tolerant hidden markov models for segmentation: application to ecgs.')]},
#  255281: {'name': 'gael de lannoy',
#   'publications': [(161584,
#     'label noise-tolerant hidden markov models for segmentation: application to ecgs.')]},
#  3326: {'name': 'michel verleysen',
#   'publications': [(161584,
#     'label noise-tolerant hidden markov models for segmentation: application to ecgs.')]},
#  20405: {'name': 'nicola barbieri',
#   'publications': [(161623,
#     'an analysis of probabilistic methods for top-n recommendation in collaborative filtering.'),
#    (638442, 'who to follow and why: link prediction with explanations.')]},
#  20407: {'name': 'giuseppe manco',
#   'publications': [(161623,
#     'an analysis of probabilistic methods for top-n recommendation in collaborative filtering.'),
#    (638442, 'who to follow and why: link prediction with explanations.')]},
#  255339: {'name': 'bernd gutmann',
#   'publications': [(161641,
#     'learning the parameters of probabilistic logic programs from interpretations.')]},
#  205380: {'name': 'ingo thon',
#   'publications': [(161641,
#     'learning the parameters of probabilistic logic programs from interpretations.')]},
#  115228: {'name': 'luc de raedt',
#   'publications': [(161641,
#     'learning the parameters of probabilistic logic programs from interpretations.')]},
#  210891: {'name': 'robert gwadera',
#   'publications': [(161677,
#     'mining actionable partial orders in collections of sequences.')]},
#  255394: {'name': 'gianluca antonini',
#   'publications': [(161677,
#     'mining actionable partial orders in collections of sequences.')]},
#  255395: {'name': 'abderrahim labbi',
#   'publications': [(161677,
#     'mining actionable partial orders in collections of sequences.')]},
#  255405: {'name': 'tianyu cao',
#   'publications': [(161687,
#     'active learning of model parameters for influence maximization.'),
#    (870141,
#     'automatic detection of craters in planetary images: an embedded framework using feature selection and boosting.')]},
#  9308: {'name': 'xindong wu',
#   'publications': [(161687,
#     'active learning of model parameters for influence maximization.'),
#    (383148, 'towards mining trapezoidal data streams.'),
#    (383188,
#     'learning label specific features for multi-label classification.')]},
#  175195: {'name': 'xiaohua tony hu',
#   'publications': [(161687,
#     'active learning of model parameters for influence maximization.')]},
#  17178: {'name': 'song wang',
#   'publications': [(161687,
#     'active learning of model parameters for influence maximization.')]},
#  176994: {'name': 'vincent graziano',
#   'publications': [(161717,
#     'unsupervised modeling of partially observable environments.')]},
#  73799: {'name': 'jan koutn&iacute;k',
#   'publications': [(161717,
#     'unsupervised modeling of partially observable environments.')]},
#  24151: {'name': 'j&uuml;rgen schmidhuber',
#   'publications': [(161717,
#     'unsupervised modeling of partially observable environments.'),
#    (733292, 'tagger: deep unsupervised perceptual grouping.')]},
#  255487: {'name': 'zhouyu fu',
#   'publications': [(161751,
#     'building sparse support vector machines for multi-instance classification.')]},
#  255488: {'name': 'guojun lu',
#   'publications': [(161751,
#     'building sparse support vector machines for multi-instance classification.')]},
#  3476: {'name': 'kai ming ting',
#   'publications': [(161751,
#     'building sparse support vector machines for multi-instance classification.')]},
#  255489: {'name': 'dengsheng zhang',
#   'publications': [(161751,
#     'building sparse support vector machines for multi-instance classification.')]},
#  166813: {'name': 'maria halkidi',
#   'publications': [(161756,
#     'a game theoretic framework for data privacy preservation in recommender systems.')]},
#  13781: {'name': 'iordanis koutsopoulos',
#   'publications': [(161756,
#     'a game theoretic framework for data privacy preservation in recommender systems.')]},
#  9741: {'name': 'thomas furmston',
#   'publications': [(161777,
#     'lagrange dual decomposition for finite horizon markov decision processes.')]},
#  8757: {'name': 'david barber',
#   'publications': [(161777,
#     'lagrange dual decomposition for finite horizon markov decision processes.')]},
#  255537: {'name': 'eraldo r. fernandes',
#   'publications': [(161790, 'learning from partially annotated sequences.')]},
#  21462: {'name': 'ulf brefeld',
#   'publications': [(161790, 'learning from partially annotated sequences.'),
#    (254014, 'document assignment in multi-site search engines.')]},
#  255578: {'name': 'christopher m. bishop',
#   'publications': [(161821,
#     'embracing uncertainty: applied machine learning comes of age.')]},
#  113776: {'name': 'weiwei cheng',
#   'publications': [(161888,
#     'preference-based policy iteration: leveraging preference learning for reinforcement learning.')]},
#  255247: {'name': 'johannes f&uuml;rnkranz',
#   'publications': [(161888,
#     'preference-based policy iteration: leveraging preference learning for reinforcement learning.')]},
#  82068: {'name': 'eyke h&uuml;llermeier',
#   'publications': [(161888,
#     'preference-based policy iteration: leveraging preference learning for reinforcement learning.')]},
#  255673: {'name': 'sang-hyeun park',
#   'publications': [(161888,
#     'preference-based policy iteration: leveraging preference learning for reinforcement learning.')]},
#  255688: {'name': 'mehrdad farajtabar',
#   'publications': [(161896,
#     'manifold coarse graining for online semi-supervised learning.'),
#    (427806,
#     'co-evolutionary dynamics of information diffusion and network structure.'),
#    (733432, 'multistage campaigning in social networks.')]},
#  255689: {'name': 'amirreza shaban',
#   'publications': [(161896,
#     'manifold coarse graining for online semi-supervised learning.')]},
#  255690: {'name': 'hamid reza rabiee',
#   'publications': [(161896,
#     'manifold coarse graining for online semi-supervised learning.')]},
#  255691: {'name': 'mohammad h. rohban',
#   'publications': [(161896,
#     'manifold coarse graining for online semi-supervised learning.')]},
#  113346: {'name': 'boris chidlovskii',
#   'publications': [(161920,
#     'learning recommendations in social media systems by weighting multiple relations.')]},
#  15924: {'name': 'rakesh agrawal 0001',
#   'publications': [(161971, 'enriching education through data mining.'),
#    (254043, 'optimizing merchant revenue with rebates.'),
#    (426495,
#     'a study of distinctiveness in web results of two search engines.'),
#    (639405, 'grouping students in educational settings.')]},
#  255814: {'name': 'gerasimos antzoulatos',
#   'publications': [(162007, '&#945;-clusterable sets.')]},
#  200773: {'name': 'michael n. vrahatis',
#   'publications': [(162007, '&#945;-clusterable sets.')]},
#  93126: {'name': 'nicolas courty',
#   'publications': [(162021,
#     'perturbo: a new classification algorithm based on the spectrum perturbations of the laplace-beltrami operator.'),
#    (730272,
#     'optimal spectral transportation with application to music transcription.'),
#    (731280, 'mapping estimation for discrete optimal transport.')]},
#  23845: {'name': 'thomas burger',
#   'publications': [(162021,
#     'perturbo: a new classification algorithm based on the spectrum perturbations of the laplace-beltrami operator.')]},
#  208589: {'name': 'johann laurent',
#   'publications': [(162021,
#     'perturbo: a new classification algorithm based on the spectrum perturbations of the laplace-beltrami operator.')]},
#  127810: {'name': 'samir al-stouhi',
#   'publications': [(162086,
#     'adaptive boosting for transfer learning using dynamic updates.')]},
#  255902: {'name': 'chandan k. reddy',
#   'publications': [(162086,
#     'adaptive boosting for transfer learning using dynamic updates.'),
#    (162674,
#     'constrained logistic regression for discriminative pattern mining.'),
#    (868651,
#     'robust prediction from multiple heterogeneous data sources with partial information.')]},
#  255926: {'name': 'aur&eacute;lien bellet',
#   'publications': [(162116,
#     'learning good edit similarities with generalization guarantees.'),
#    (732891,
#     'on graph reconstruction via empirical risk minimization: fast learning rates and scalability.')]},
#  9503: {'name': 'amaury habrard',
#   'publications': [(162116,
#     'learning good edit similarities with generalization guarantees.'),
#    (731280, 'mapping estimation for discrete optimal transport.')]},
#  9505: {'name': 'marc sebban',
#   'publications': [(162116,
#     'learning good edit similarities with generalization guarantees.'),
#    (730342,
#     'beta-risk: a new surrogate risk for learning from weakly labeled data.')]},
#  9068: {'name': 'r&oacute;bert busa-fekete',
#   'publications': [(162135,
#     'a robust ranking methodology based on diverse calibration of adaboost.')]},
#  9046: {'name': 'bal&aacute;zs k&eacute;gl',
#   'publications': [(162135,
#     'a robust ranking methodology based on diverse calibration of adaboost.')]},
#  9069: {'name': 'tam&aacute;s &eacute;ltet&ouml;',
#   'publications': [(162135,
#     'a robust ranking methodology based on diverse calibration of adaboost.')]},
#  9070: {'name': 'gy&ouml;rgy szarvas',
#   'publications': [(162135,
#     'a robust ranking methodology based on diverse calibration of adaboost.')]},
#  255950: {'name': 'albert-l&aacute;szl&oacute; barab&aacute;si',
#   'publications': [(162140,
#     'human dynamics: from human mobility to predictability.')]},
#  255996: {'name': 'hiromi arai',
#   'publications': [(162188,
#     'privacy preserving semi-supervised learning for labeled graphs.'),
#    (732068, 'differential privacy without sensitivity.')]},
#  20199: {'name': 'jun sakuma',
#   'publications': [(162188,
#     'privacy preserving semi-supervised learning for labeled graphs.')]},
#  124828: {'name': 'alberto bertoni',
#   'publications': [(162227,
#     'cosnet: a cost sensitive neural network for semi-supervised learning in graphs.')]},
#  239007: {'name': 'marco frasca 0001',
#   'publications': [(162227,
#     'cosnet: a cost sensitive neural network for semi-supervised learning in graphs.')]},
#  189237: {'name': 'giorgio valentini',
#   'publications': [(162227,
#     'cosnet: a cost sensitive neural network for semi-supervised learning in graphs.')]},
#  255823: {'name': 'heikki mannila',
#   'publications': [(162232, 'permutation structure in 0-1 data.')]},
#  256123: {'name': 'kais allab',
#   'publications': [(162307,
#     'constraint selection for semi-supervised topological clustering.'),
#    (383301, 'simultaneous semi-nmf and pca for clustering.')]},
#  256124: {'name': 'khalid benabdeslem',
#   'publications': [(162307,
#     'constraint selection for semi-supervised topological clustering.'),
#    (162460,
#     'constrained laplacian score for semi-supervised feature selection.')]},
#  8985: {'name': 'quanquan gu',
#   'publications': [(162309, 'linear discriminant dimensionality reduction.'),
#    (639653,
#     'cluscite: effective citation recommendation by information network-based clustering.'),
#    (658590, 'contextual bandits in a collaborative environment.'),
#    (730877, 'semiparametric differential graph models.')]},
#  8987: {'name': 'zhenhui li',
#   'publications': [(162309, 'linear discriminant dimensionality reduction.'),
#    (427067, 'semmobi: a semantic annotation system for mobility data.')]},
#  8988: {'name': 'jiawei han 0001',
#   'publications': [(162309, 'linear discriminant dimensionality reduction.'),
#    (175585, 'mining quality phrases from massive text corpora.'),
#    (342453, 'community cores: removing size bias from community detection.'),
#    (382686,
#     'knowsim: a document similarity measure on structured heterogeneous information networks.'),
#    (383858,
#     'mining multi-aspect reflection of news events in twitter: discovery, linking and presentation.'),
#    (638481,
#     'bringing structure to text: mining phrases, entities, topics, and hierarchies.'),
#    (639113, 'towards scalable critical alert mining.'),
#    (639653,
#     'cluscite: effective citation recommendation by information network-based clustering.'),
#    (659863,
#     'geoburst: real-time local event detection in geo-tagged tweet streams.'),
#    (868121, 'mapping web pages to database records via link paths.'),
#    (869208, 'mining topic-level influence in heterogeneous networks.'),
#    (869713,
#     'shrink: a structural clustering algorithm for detecting hierarchical communities in networks.'),
#    (869855, 'visual cube and on-line analytical processing of images.')]},
#  19285: {'name': 'stephan g&uuml;nnemann',
#   'publications': [(162311,
#     'db-csc: a density-based approach for subspace clustering in graphs with feature vectors.'),
#    (382979, 'automatic taxonomy extraction from bipartite graphs.'),
#    (427879, 'extracting taxonomies from bipartite graphs.'),
#    (639152,
#     'smvc: semi-supervised multi-view clustering in subspace projections.'),
#    (639294,
#     'detecting anomalies in dynamic rating data: a robust probabilistic model for rating evolution.')]},
#  19460: {'name': 'brigitte boden',
#   'publications': [(162311,
#     'db-csc: a density-based approach for subspace clustering in graphs with feature vectors.')]},
#  8612: {'name': 'thomas seidl 0001',
#   'publications': [(162311,
#     'db-csc: a density-based approach for subspace clustering in graphs with feature vectors.'),
#    (639152,
#     'smvc: semi-supervised multi-view clustering in subspace projections.'),
#    (871198, 'adaptive outlierness for subspace outlier ranking.')]},
#  255494: {'name': 'olivier verscheure',
#   'publications': [(162328,
#     'smart cities: how data mining and optimization can shape future cities.')]},
#  256146: {'name': 'wendelin b&ouml;hmer',
#   'publications': [(162332,
#     'regularized sparse kernel slow feature analysis.')]},
#  256147: {'name': 'steffen gr&uuml;new&auml;lder',
#   'publications': [(162332,
#     'regularized sparse kernel slow feature analysis.')]},
#  9771: {'name': 'hannes nickisch',
#   'publications': [(162332,
#     'regularized sparse kernel slow feature analysis.')]},
#  256148: {'name': 'klaus obermayer',
#   'publications': [(162332,
#     'regularized sparse kernel slow feature analysis.')]},
#  20336: {'name': 'neel sundaresan',
#   'publications': [(162342, 'data science and machine learning at scale.'),
#    (253807, 'ebay: an e-commerce marketplace as a complex network.'),
#    (253871, 'query suggestion for e-commerce sites.'),
#    (638940,
#     'large scale visual recommendations from street fashion images.')]},
#  256176: {'name': 'aris anagnostopoulos',
#   'publications': [(162358,
#     'peer and authority pressure in information-propagation models.'),
#    (175568,
#     'the importance of being expert: efficient max-finding in crowdsourcing.'),
#    (254068, 'an optimization framework for query recommendation.'),
#    (254234, 'stochastic query covering.'),
#    (342298, 'targeted interest-driven advertising in cities using twitter.'),
#    (354200, 'algorithms on evolving graphs.'),
#    (382418, 'learning a macroscopic model of cultural dynamics.'),
#    (425337, 'viral misinformation: the role of homophily and polarization.'),
#    (427289, 'online team formation in social networks.'),
#    (486893, 'online network design with outliers.'),
#    (494767,
#     'constant integrality gap lp formulations of unsplittable flow on a path.'),
#    (544318,
#     'a mazing 2+<i>&#8714;</i> approximation for unsplittable flow on a path.'),
#    (638333, 'event detection in activity networks.'),
#    (658645, 'network-aware recommendations of novel tweets.'),
#    (731279, 'community detection on evolving graphs.'),
#    (866799, 'inefficiency of games with social context.'),
#    (869138, 'power in unity: forming teams in large-scale community systems.'),
#    (954951, 'bidding strategies for fantasy-sports auctions.'),
#    (979491,
#     'competitive influence in social networks: convergence, submodularity, and competition effects.')]},
#  256177: {'name': 'george brova',
#   'publications': [(162358,
#     'peer and authority pressure in information-propagation models.')]},
#  255328: {'name': 'evimaria terzi',
#   'publications': [(162358,
#     'peer and authority pressure in information-propagation models.'),
#    (638644, 'profit-maximizing cluster hires.'),
#    (639405, 'grouping students in educational settings.')]},
#  256188: {'name': 'vasilis aggelis',
#   'publications': [(162367,
#     'reading customers needs and expectations with analytics.')]},
#  256159: {'name': 'henrik grosskreutz',
#   'publications': [(162404,
#     'fast and memory-efficient discovery of the top-k relevant subgroups in a reduced candidate space.')]},
#  256133: {'name': 'daniel paurat',
#   'publications': [(162404,
#     'fast and memory-efficient discovery of the top-k relevant subgroups in a reduced candidate space.')]},
#  256264: {'name': 'roberto guzm&aacute;n-mart&iacute;nez',
#   'publications': [(162448,
#     'feature selection stability assessment based on the jensen-shannon divergence.')]},
#  256265: {'name': 'roc&iacute;o ala&iacute;z-rodr&iacute;guez',
#   'publications': [(162448,
#     'feature selection stability assessment based on the jensen-shannon divergence.')]},
#  256276: {'name': 'mohammed hindawi',
#   'publications': [(162460,
#     'constrained laplacian score for semi-supervised feature selection.')]},
#  25696: {'name': 'gianluca bontempi',
#   'publications': [(162498,
#     'a selecting-the-best method for budgeted model selection.')]},
#  255805: {'name': 'olivier caelen',
#   'publications': [(162498,
#     'a selecting-the-best method for budgeted model selection.')]},
#  72882: {'name': 'muhammad awais',
#   'publications': [(162499, 'novel fusion methods for pattern recognition.')]},
#  72883: {'name': 'fei yan',
#   'publications': [(162499, 'novel fusion methods for pattern recognition.')]},
#  71582: {'name': 'krystian mikolajczyk',
#   'publications': [(162499, 'novel fusion methods for pattern recognition.')]},
#  71969: {'name': 'josef kittler',
#   'publications': [(162499, 'novel fusion methods for pattern recognition.')]},
#  9772: {'name': 'borja balle',
#   'publications': [(162537,
#     'a spectral learning algorithm for finite state transducers.')]},
#  114626: {'name': 'ariadna quattoni',
#   'publications': [(162537,
#     'a spectral learning algorithm for finite state transducers.')]},
#  114625: {'name': 'xavier carreras',
#   'publications': [(162537,
#     'a spectral learning algorithm for finite state transducers.')]},
#  114483: {'name': 'changyou chen',
#   'publications': [(162546,
#     'sampling table configurations for the hierarchical poisson-dirichlet process.'),
#    (731257, 'stochastic gradient mcmc with stale gradients.'),
#    (732029, 'towards unifying hamiltonian monte carlo and slice sampling.')]},
#  202882: {'name': 'lan du',
#   'publications': [(162546,
#     'sampling table configurations for the hierarchical poisson-dirichlet process.')]},
#  256135: {'name': 'wray l. buntine',
#   'publications': [(162546,
#     'sampling table configurations for the hierarchical poisson-dirichlet process.'),
#    (638428, 'experiments with non-parametric topic models.'),
#    (658023,
#     'pulp: a system for exploratory search of scientific literature.')]},
#  252278: {'name': 'radu jurca',
#   'publications': [(162589, 'algorithms and challenges on the geoweb.')]},
#  83637: {'name': 'valdinei freire da silva',
#   'publications': [(162622,
#     'a geometric approach to find nondominated policies to imprecise reward mdps.')]},
#  83639: {'name': 'anna helena reali costa',
#   'publications': [(162622,
#     'a geometric approach to find nondominated policies to imprecise reward mdps.')]},
#  255300: {'name': 'st&eacute;phan cl&eacute;men&ccedil;on',
#   'publications': [(162632, 'clustering rankings in the fourier domain.'),
#    (732891,
#     'on graph reconstruction via empirical risk minimization: fast learning rates and scalability.')]},
#  21056: {'name': 'romaric gaudel',
#   'publications': [(162632, 'clustering rankings in the fourier domain.')]},
#  70758: {'name': 'j&eacute;r&eacute;mie jakubowicz',
#   'publications': [(162632, 'clustering rankings in the fourier domain.')]},
#  256482: {'name': 'andrei z. broder',
#   'publications': [(162661,
#     'highly dimensional problems in computational advertising.'),
#    (253699, 'introduction to display advertising: a half-day tutorial.'),
#    (253723, 'automatic generation of bid phrases for online advertising.'),
#    (253803,
#     'anatomy of the long tail: ordinary people with extraordinary tastes.'),
#    (254168, 'bid generation for advanced match in sponsored search.'),
#    (870107, 'exploiting site-level information to improve web search.')]},
#  256500: {'name': 'rajul anand',
#   'publications': [(162674,
#     'constrained logistic regression for discriminative pattern mining.')]},
#  20392: {'name': 'mihajlo grbovic',
#   'publications': [(162686,
#     'tracking concept change with incremental boosting by minimization of the evolving exponential loss.'),
#    (425244, 'hate speech detection with comment embeddings.'),
#    (425764,
#     'large-scale contextual query-to-ad matching and retrieval system for sponsored search: (abstract).'),
#    (426399, 'search retargeting using directed query embeddings.'),
#    (427503,
#     'querycategorizr: a large-scale semi-supervised system for categorization of web search queries.'),
#    (659765,
#     'scalable semantic matching of queries to ads in sponsored search advertising.')]},
#  8857: {'name': 'slobodan vucetic',
#   'publications': [(162686,
#     'tracking concept change with incremental boosting by minimization of the evolving exponential loss.')]},
#  256366: {'name': 'marco gori',
#   'publications': [(162730, 'learning from constraints.')]},
#  255759: {'name': 'gabriel dulac-arnold',
#   'publications': [(162753,
#     'datum-wise classification: a sequential approach to sparsity.')]},
#  255760: {'name': 'ludovic denoyer',
#   'publications': [(162753,
#     'datum-wise classification: a sequential approach to sparsity.')]},
#  8874: {'name': 'philippe preux',
#   'publications': [(162753,
#     'datum-wise classification: a sequential approach to sparsity.')]},
#  19794: {'name': 'patrick gallinari',
#   'publications': [(162753,
#     'datum-wise classification: a sequential approach to sparsity.'),
#    (342253,
#     'dynamic data capture from social media streams: a contextual bandit approach.')]},
#  9451: {'name': 'mario frank',
#   'publications': [(162795,
#     'the minimum transfer cost principle for model-order selection.')]},
#  8350: {'name': 'morteza haghir chehreghani',
#   'publications': [(162795,
#     'the minimum transfer cost principle for model-order selection.')]},
#  8352: {'name': 'joachim m. buhmann',
#   'publications': [(162795,
#     'the minimum transfer cost principle for model-order selection.'),
#    (731065,
#     'scalable adaptive stochastic optimization using random projections.')]},
#  151570: {'name': 'riad akrour',
#   'publications': [(162806, 'preference-based policy learning.')]},
#  43462: {'name': 'marc schoenauer',
#   'publications': [(162806, 'preference-based policy learning.')]},
#  9388: {'name': 'mich&egrave;le sebag',
#   'publications': [(162806, 'preference-based policy learning.')]},
#  1632: {'name': 'wen sun',
#   'publications': [(175151,
#     'sqlgraph: an efficient relational-based property graph store.')]},
#  217858: {'name': 'achille fokoue',
#   'publications': [(175151,
#     'sqlgraph: an efficient relational-based property graph store.')]},
#  271609: {'name': 'kavitha srinivas',
#   'publications': [(175151,
#     'sqlgraph: an efficient relational-based property graph store.')]},
#  17344: {'name': 'anastasios kementsietsidis',
#   'publications': [(175151,
#     'sqlgraph: an efficient relational-based property graph store.')]},
#  16239: {'name': 'gang hu',
#   'publications': [(175151,
#     'sqlgraph: an efficient relational-based property graph store.')]},
#  271610: {'name': 'guo tong xie',
#   'publications': [(175151,
#     'sqlgraph: an efficient relational-based property graph store.')]},
#  8819: {'name': 'markus weimer',
#   'publications': [(175152,
#     'reef: retainable evaluator execution framework.')]},
#  271611: {'name': 'yingda chen',
#   'publications': [(175152,
#     'reef: retainable evaluator execution framework.')]},
#  16249: {'name': 'byung-gon chun',
#   'publications': [(175152,
#     'reef: retainable evaluator execution framework.')]},
#  19355: {'name': 'tyson condie',
#   'publications': [(175152,
#     'reef: retainable evaluator execution framework.')]},
#  16145: {'name': 'carlo curino',
#   'publications': [(175152, 'reef: retainable evaluator execution framework.'),
#    (175452, 'benchpress: dynamic workload control in the oltp-bench testbed.'),
#    (175649,
#     'apache tez: a unifying framework for modeling and building data processing applications.'),
#    (176000,
#     'wanalytics: geo-distributed analytics for a data intensive world.')]},
#  18433: {'name': 'chris douglas',
#   'publications': [(175152,
#     'reef: retainable evaluator execution framework.')]},
#  223848: {'name': 'yunseong lee',
#   'publications': [(175152,
#     'reef: retainable evaluator execution framework.')]},
#  271612: {'name': 'tony majestro',
#   'publications': [(175152,
#     'reef: retainable evaluator execution framework.')]},
#  175489: {'name': 'dahlia malkhi',
#   'publications': [(175152,
#     'reef: retainable evaluator execution framework.')]},
#  271613: {'name': 'sergiy matusevych',
#   'publications': [(175152,
#     'reef: retainable evaluator execution framework.')]},
#  17368: {'name': 'brandon myers',
#   'publications': [(175152,
#     'reef: retainable evaluator execution framework.')]},
#  271614: {'name': 'shravan m. narayanamurthy',
#   'publications': [(175152,
#     'reef: retainable evaluator execution framework.')]},
#  17611: {'name': 'raghu ramakrishnan',
#   'publications': [(175152, 'reef: retainable evaluator execution framework.'),
#    (176093,
#     'machine learning and databases: the sound of things to come or a cacophony of hype?'),
#    (638639, 'does social good justify risking personal privacy?')]},
#  16521: {'name': 'sriram rao',
#   'publications': [(175152,
#     'reef: retainable evaluator execution framework.')]},
#  168357: {'name': 'russell sears',
#   'publications': [(175152, 'reef: retainable evaluator execution framework.'),
#    (176001,
#     'purity: building fast, highly-available enterprise flash storage from commodity components.')]},
#  271615: {'name': 'beysim sezgin',
#   'publications': [(175152,
#     'reef: retainable evaluator execution framework.')]},
#  271616: {'name': 'julia wang',
#   'publications': [(175152,
#     'reef: retainable evaluator execution framework.')]},
#  17509: {'name': 'zhewei wei',
#   'publications': [(175153, 'persistent data sketching.')]},
#  17973: {'name': 'ge luo',
#   'publications': [(175153, 'persistent data sketching.')]},
#  17974: {'name': 'ke yi',
#   'publications': [(175153, 'persistent data sketching.'),
#    (175372,
#     'storm: spatio-temporal online reasoning and management of large spatio-temporal data.'),
#    (487521, 'clustering with diversity.')]},
#  16665: {'name': 'xiaoyong du',
#   'publications': [(175153, 'persistent data sketching.'),
#    (869907, 'approximate membership localization (aml) for web-based join.')]},
#  16837: {'name': 'ji-rong wen',
#   'publications': [(175153, 'persistent data sketching.'),
#    (253842, 'multi-dimensional search result diversification.'),
#    (254150,
#     'revisiting globally sorted indexes for efficient document retrieval.'),
#    (658064, 'evaluating search result diversity using intent hierarchies.'),
#    (870739, 'efficient term proximity search with term-pair indexes.')]},
#  16867: {'name': 'shaoxu song',
#   'publications': [(175159,
#     'screen: stream data cleaning under speed constraints.'),
#    (176454,
#     'how to build templates for rdf question/answering: an uncertain graph similarity join approach.'),
#    (870177, 'efficient set-correlation operator inside databases.')]},
#  271623: {'name': 'aoqian zhang',
#   'publications': [(175159,
#     'screen: stream data cleaning under speed constraints.')]},
#  17824: {'name': 'jianmin wang 0001',
#   'publications': [(175159,
#     'screen: stream data cleaning under speed constraints.'),
#    (658101,
#     'composite correlation quantization for efficient multimodal retrieval.'),
#    (732493,
#     'unsupervised domain adaptation with residual transfer networks.')]},
#  15938: {'name': 'philip s. yu',
#   'publications': [(175159,
#     'screen: stream data cleaning under speed constraints.'),
#    (382996,
#     'convex approximation to the integral mixture models using step functions.'),
#    (383083,
#     'mining brain networks using multiple side views for neurological disorder identification.'),
#    (383756,
#     'ensemble of diverse sparsifications for link prediction in large-scale networks.'),
#    (383768, 'multiple anonymized social networks alignment.'),
#    (426936, 'community detection in incomplete information networks.'),
#    (638985,
#     'class-distribution regularized consensus maximization for alleviating overfitting in model combination.'),
#    (639376,
#     'mmrate: inferring multi-aspect diffusion networks with multi-pattern cascades.'),
#    (640028, 'meta-path based multi-network collective link prediction.'),
#    (658101,
#     'composite correlation quantization for efficient multimodal retrieval.'),
#    (868114, 'on wavelet decomposition of uncertain time series data sets.'),
#    (870205,
#     'orientation distance-based discriminative feature extraction for multi-class classification.')]},
#  271632: {'name': 'youze tang',
#   'publications': [(175172,
#     'influence maximization in near-linear time: a martingale approach.')]},
#  271633: {'name': 'yanchen shi',
#   'publications': [(175172,
#     'influence maximization in near-linear time: a martingale approach.')]},
#  16483: {'name': 'xiaokui xiao',
#   'publications': [(175172,
#     'influence maximization in near-linear time: a martingale approach.'),
#    (175485, 'private release of graph statistics using ladder functions.'),
#    (175648,
#     'efficient route planning on public transportation networks: a labelling approach.'),
#    (175758, 'crowd-based deduplication: an adaptive approach.')]},
#  17423: {'name': 'ju fan',
#   'publications': [(175175, 'icrowd: an adaptive crowdsourcing framework.')]},
#  15815: {'name': 'guoliang li 0001',
#   'publications': [(175175, 'icrowd: an adaptive crowdsourcing framework.'),
#    (175179, 'efficient similarity join and search on multi-attribute data.'),
#    (175608,
#     'location-aware pub/sub system: when continuous moving queries meet dynamic event streams.'),
#    (176613,
#     'qasca: a quality-aware task assignment system for crowdsourcing applications.'),
#    (868056,
#     'extending dictionary-based entity extraction to tolerate errors.')]},
#  17426: {'name': 'beng chin ooi',
#   'publications': [(175175, 'icrowd: an adaptive crowdsourcing framework.'),
#    (176083, 'scalable distributed stream join processing.')]},
#  16053: {'name': 'kian-lee tan',
#   'publications': [(175175, 'icrowd: an adaptive crowdsourcing framework.'),
#    (175608,
#     'location-aware pub/sub system: when continuous moving queries meet dynamic event streams.'),
#    (639416,
#     'differentially private network data release via structural inference.')]},
#  15816: {'name': 'jianhua feng',
#   'publications': [(175175, 'icrowd: an adaptive crowdsourcing framework.'),
#    (176613,
#     'qasca: a quality-aware task assignment system for crowdsourcing applications.'),
#    (868056,
#     'extending dictionary-based entity extraction to tolerate errors.')]},
#  16309: {'name': 'jieying she',
#   'publications': [(175178,
#     'utility-aware social event-participant planning.')]},
#  15983: {'name': 'yongxin tong',
#   'publications': [(175178,
#     'utility-aware social event-participant planning.'),
#    (382561, 'crowdtc: crowdsourced taxonomy construction.'),
#    (639860,
#     'tcs: efficient topic discovery over crowd-oriented service data.')]},
#  15982: {'name': 'lei chen 0002',
#   'publications': [(175178,
#     'utility-aware social event-participant planning.'),
#    (175532, 'online video recommendation in sharing community.'),
#    (382561, 'crowdtc: crowdsourced taxonomy construction.'),
#    (639860,
#     'tcs: efficient topic discovery over crowd-oriented service data.'),
#    (639962,
#     'from labor to trader: opinion elicitation via online crowds as a market.'),
#    (868111, 'automatically weighting tags in xml collection.'),
#    (870177, 'efficient set-correlation operator inside databases.')]},
#  17853: {'name': 'jian he',
#   'publications': [(175179,
#     'efficient similarity join and search on multi-attribute data.')]},
#  16752: {'name': 'dong deng',
#   'publications': [(175179,
#     'efficient similarity join and search on multi-attribute data.'),
#    (868056,
#     'extending dictionary-based entity extraction to tolerate errors.')]},
#  17184: {'name': 'jian li',
#   'publications': [(175179,
#     'efficient similarity join and search on multi-attribute data.'),
#    (487521, 'clustering with diversity.'),
#    (494782, 'matroid and knapsack center problems.'),
#    (544710,
#     'a constant factor approximation algorithm for fault-tolerant <i>k</i>-median.'),
#    (733551,
#     'combinatorial multi-armed bandit with general reward functions.')]},
#  17829: {'name': 'zhiwei zhang',
#   'publications': [(175191,
#     'divide &amp; conquer: i/o efficient depth-first search.'),
#    (658268,
#     'learning for efficient supervised query expansion via two-stage feature selection.')]},
#  15850: {'name': 'jeffrey xu yu',
#   'publications': [(175191,
#     'divide &amp; conquer: i/o efficient depth-first search.'),
#    (175779,
#     'index-based optimal algorithms for computing steiner components with maximum connectivity.'),
#    (176454,
#     'how to build templates for rdf question/answering: an uncertain graph similarity join approach.'),
#    (383533, 'scalable hypergraph learning and processing.'),
#    (869010,
#     'energy-efficient top-k query processing in wireless sensor networks.')]},
#  16486: {'name': 'lu qin',
#   'publications': [(175191,
#     'divide &amp; conquer: i/o efficient depth-first search.'),
#    (175779,
#     'index-based optimal algorithms for computing steiner components with maximum connectivity.')]},
#  18268: {'name': 'zechao shang',
#   'publications': [(175191,
#     'divide &amp; conquer: i/o efficient depth-first search.')]},
#  271670: {'name': 'silu huang',
#   'publications': [(175204, 'minimum spanning trees in temporal graphs.')]},
#  17466: {'name': 'ada wai-chee fu',
#   'publications': [(175204, 'minimum spanning trees in temporal graphs.'),
#    (175296, 'exact top-k nearest keyword search in large networks.')]},
#  271671: {'name': 'ruifeng liu',
#   'publications': [(175204, 'minimum spanning trees in temporal graphs.')]},
#  271722: {'name': 'mukund deshpande',
#   'publications': [(175240,
#     'shareinsights: an unified approach to full-stack data processing.')]},
#  271723: {'name': 'dhruva ray',
#   'publications': [(175240,
#     'shareinsights: an unified approach to full-stack data processing.')]},
#  271724: {'name': 'sameer dixit',
#   'publications': [(175240,
#     'shareinsights: an unified approach to full-stack data processing.')]},
#  271725: {'name': 'avadhoot agasti',
#   'publications': [(175240,
#     'shareinsights: an unified approach to full-stack data processing.')]},
#  16543: {'name': 'farhan tauheed',
#   'publications': [(175249,
#     'thermal-join: a scalable spatial join for dynamic workloads.')]},
#  16545: {'name': 'thomas heinis',
#   'publications': [(175249,
#     'thermal-join: a scalable spatial join for dynamic workloads.')]},
#  16458: {'name': 'anastasia ailamaki',
#   'publications': [(175249,
#     'thermal-join: a scalable spatial join for dynamic workloads.')]},
#  101615: {'name': 'saket gurukar',
#   'publications': [(175253,
#     'commit: a scalable approach to mining communication motifs from dynamic networks.')]},
#  15939: {'name': 'sayan ranu',
#   'publications': [(175253,
#     'commit: a scalable approach to mining communication motifs from dynamic networks.'),
#    (382782, 'geo-social clustering of places from check-in data.'),
#    (426577, 'recommendations to boost content spread in social networks.')]},
#  17770: {'name': 'balaraman ravindran',
#   'publications': [(175253,
#     'commit: a scalable approach to mining communication motifs from dynamic networks.'),
#    (383469, 'nonparametric poisson factorization machine.'),
#    (981185,
#     'near optimal strategies for targeted marketing in social networks.')]},
#  15871: {'name': 'mingwang tang',
#   'publications': [(175257, 'distributed online tracking.'),
#    (639685, 'scalable histograms on large probabilistic data.')]},
#  15872: {'name': 'feifei li 0001',
#   'publications': [(175257, 'distributed online tracking.'),
#    (175372,
#     'storm: spatio-temporal online reasoning and management of large spatio-temporal data.'),
#    (639685, 'scalable histograms on large probabilistic data.')]},
#  18686: {'name': 'yufei tao',
#   'publications': [(175257, 'distributed online tracking.'),
#    (175724, 'dbscan revisited: mis-claim, un-fixability, and approximation.'),
#    (544818, 'concurrent range reporting in two-dimensional space.')]},
#  271767: {'name': 'zuhair khayyat',
#   'publications': [(175262, 'bigdansing: a system for big data cleansing.')]},
#  16222: {'name': 'ihab f. ilyas',
#   'publications': [(175262, 'bigdansing: a system for big data cleansing.'),
#    (175587,
#     'katara: a data cleaning system powered by knowledge bases and crowdsourcing.'),
#    (659076, 'lonlies: estimating property values for long tail entities.')]},
#  264678: {'name': 'alekh jindal',
#   'publications': [(175262, 'bigdansing: a system for big data cleansing.')]},
#  17002: {'name': 'samuel madden',
#   'publications': [(175262, 'bigdansing: a system for big data cleansing.')]},
#  15858: {'name': 'mourad ouzzani',
#   'publications': [(175262, 'bigdansing: a system for big data cleansing.'),
#    (175587,
#     'katara: a data cleaning system powered by knowledge bases and crowdsourcing.'),
#    (176229, 'dataxformer: an interactive data transformation tool.')]},
#  16438: {'name': 'paolo papotti',
#   'publications': [(175262, 'bigdansing: a system for big data cleansing.'),
#    (175587,
#     'katara: a data cleaning system powered by knowledge bases and crowdsourcing.'),
#    (176229, 'dataxformer: an interactive data transformation tool.')]},
#  16884: {'name': 'jorge-arnulfo quian&eacute;-ruiz',
#   'publications': [(175262, 'bigdansing: a system for big data cleansing.')]},
#  16830: {'name': 'nan tang 0001',
#   'publications': [(175262, 'bigdansing: a system for big data cleansing.'),
#    (175587,
#     'katara: a data cleaning system powered by knowledge bases and crowdsourcing.')]},
#  271768: {'name': 'si yin',
#   'publications': [(175262, 'bigdansing: a system for big data cleansing.')]},
#  17206: {'name': 'jignesh m. patel',
#   'publications': [(175275, 'from data to insights @ bare metal speed.'),
#    (175366,
#     'a padded encoding scheme to accelerate scans by leveraging skew.'),
#    (175659, 'learning generalized linear models over normalized data.'),
#    (176463, 'twitter heron: stream processing at scale.')]},
#  271791: {'name': 'li-yan yuan',
#   'publications': [(175283,
#     'a demonstration of rubato db: a highly scalable newsql database system for oltp and big data applications.')]},
#  271792: {'name': 'lengdong wu',
#   'publications': [(175283,
#     'a demonstration of rubato db: a highly scalable newsql database system for oltp and big data applications.')]},
#  111329: {'name': 'jia-huai you',
#   'publications': [(175283,
#     'a demonstration of rubato db: a highly scalable newsql database system for oltp and big data applications.')]},
#  271793: {'name': 'yan chi',
#   'publications': [(175283,
#     'a demonstration of rubato db: a highly scalable newsql database system for oltp and big data applications.')]},
#  271797: {'name': 'yonathan perez',
#   'publications': [(175290,
#     'ringo: interactive graph analytics on big-memory machines.')]},
#  271798: {'name': 'rok sosic',
#   'publications': [(175290,
#     'ringo: interactive graph analytics on big-memory machines.'),
#    (425805,
#     'large scale network analytics with snap: tutorial at the world wide web 2015 conference.')]},
#  271799: {'name': 'arijit banerjee',
#   'publications': [(175290,
#     'ringo: interactive graph analytics on big-memory machines.')]},
#  271800: {'name': 'rohan puttagunta',
#   'publications': [(175290,
#     'ringo: interactive graph analytics on big-memory machines.')]},
#  271801: {'name': 'martin raison',
#   'publications': [(175290,
#     'ringo: interactive graph analytics on big-memory machines.')]},
#  271802: {'name': 'pararth shah',
#   'publications': [(175290,
#     'ringo: interactive graph analytics on big-memory machines.')]},
#  21484: {'name': 'jure leskovec',
#   'publications': [(175290,
#     'ringo: interactive graph analytics on big-memory machines.'),
#    (253622, 'correcting for missing data in information cascades.'),
#    (254038,
#     'supervised random walks: predicting and recommending links in social networks.'),
#    (254166, 'patterns of temporal variation in online media.'),
#    (425548, 'human wayfinding in information networks.'),
#    (425805,
#     'large scale network analytics with snap: tutorial at the world wide web 2015 conference.')]},
#  271681: {'name': 'minhao jiang',
#   'publications': [(175296,
#     'exact top-k nearest keyword search in large networks.')]},
#  271811: {'name': 'raymond chi-wing wong',
#   'publications': [(175296,
#     'exact top-k nearest keyword search in large networks.'),
#    (176616, 'k-hit query: top-k query with probabilistic utility function.')]},
#  271819: {'name': 'paul suganthan g. c.',
#   'publications': [(175303,
#     'why big data industrial systems need rules and what we can do about it.')]},
#  19391: {'name': 'chong sun',
#   'publications': [(175303,
#     'why big data industrial systems need rules and what we can do about it.')]},
#  271820: {'name': 'krishna gayatri k.',
#   'publications': [(175303,
#     'why big data industrial systems need rules and what we can do about it.')]},
#  271821: {'name': 'haojun zhang',
#   'publications': [(175303,
#     'why big data industrial systems need rules and what we can do about it.')]},
#  271822: {'name': 'frank yang',
#   'publications': [(175303,
#     'why big data industrial systems need rules and what we can do about it.')]},
#  271823: {'name': 'narasimhan rampalli',
#   'publications': [(175303,
#     'why big data industrial systems need rules and what we can do about it.')]},
#  271824: {'name': 'shishir prasad',
#   'publications': [(175303,
#     'why big data industrial systems need rules and what we can do about it.')]},
#  271825: {'name': 'esteban arcaute',
#   'publications': [(175303,
#     'why big data industrial systems need rules and what we can do about it.')]},
#  271826: {'name': 'ganesh krishnan',
#   'publications': [(175303,
#     'why big data industrial systems need rules and what we can do about it.')]},
#  271827: {'name': 'rohit deep',
#   'publications': [(175303,
#     'why big data industrial systems need rules and what we can do about it.')]},
#  271828: {'name': 'vijay raghavendra',
#   'publications': [(175303,
#     'why big data industrial systems need rules and what we can do about it.')]},
#  16098: {'name': 'anhai doan',
#   'publications': [(175303,
#     'why big data industrial systems need rules and what we can do about it.')]},
#  16390: {'name': 'peter alvaro',
#   'publications': [(175310, 'lineage-driven fault injection.')]},
#  271839: {'name': 'joshua rosen',
#   'publications': [(175310, 'lineage-driven fault injection.')]},
#  16392: {'name': 'joseph m. hellerstein',
#   'publications': [(175310, 'lineage-driven fault injection.'),
#    (175949,
#     'feral concurrency control: an empirical investigation of modern application integrity.')]},
#  21665: {'name': 'tao guo',
#   'publications': [(175312,
#     'efficient algorithms for answering the m-closest keywords query.')]},
#  17292: {'name': 'xin cao',
#   'publications': [(175312,
#     'efficient algorithms for answering the m-closest keywords query.')]},
#  15866: {'name': 'gao cong',
#   'publications': [(175312,
#     'efficient algorithms for answering the m-closest keywords query.'),
#    (176134, 'diversity-aware top-k publish/subscribe for text stream.'),
#    (639916, 'com: a generative model for group recommendation.'),
#    (868423,
#     'exploring domain-specific term weight in archived question search.')]},
#  218394: {'name': 'katerina doka',
#   'publications': [(175348,
#     'ires: intelligent, multi-engine resource scheduler for big data analytics workflows.'),
#    (175776,
#     'modissense: a distributed spatio-temporal and textual processing platform for social networking services.'),
#    (871186, 'brown dwarf: a p2p data-warehousing system.')]},
#  271859: {'name': 'nikolaos papailiou',
#   'publications': [(175348,
#     'ires: intelligent, multi-engine resource scheduler for big data analytics workflows.'),
#    (175822, 'graph-aware, workload-adaptive sparql query caching.')]},
#  19052: {'name': 'dimitrios tsoumakos',
#   'publications': [(175348,
#     'ires: intelligent, multi-engine resource scheduler for big data analytics workflows.'),
#    (175822, 'graph-aware, workload-adaptive sparql query caching.'),
#    (871186, 'brown dwarf: a p2p data-warehousing system.')]},
#  271860: {'name': 'christos mantas',
#   'publications': [(175348,
#     'ires: intelligent, multi-engine resource scheduler for big data analytics workflows.')]},
#  18210: {'name': 'nectarios koziris',
#   'publications': [(175348,
#     'ires: intelligent, multi-engine resource scheduler for big data analytics workflows.'),
#    (175776,
#     'modissense: a distributed spatio-temporal and textual processing platform for social networking services.'),
#    (175822, 'graph-aware, workload-adaptive sparql query caching.'),
#    (871186, 'brown dwarf: a p2p data-warehousing system.')]},
#  15884: {'name': 'abdallah salama',
#   'publications': [(175351,
#     'cost-based fault-tolerance for parallel data processing.'),
#    (176439, 'locality-aware partitioning in parallel database systems.')]},
#  15883: {'name': 'carsten binnig',
#   'publications': [(175351,
#     'cost-based fault-tolerance for parallel data processing.'),
#    (176439, 'locality-aware partitioning in parallel database systems.')]},
#  15986: {'name': 'tim kraska',
#   'publications': [(175351,
#     'cost-based fault-tolerance for parallel data processing.'),
#    (176093,
#     'machine learning and databases: the sound of things to come or a cacophony of hype?')]},
#  15885: {'name': 'erfan zamanian',
#   'publications': [(175351,
#     'cost-based fault-tolerance for parallel data processing.'),
#    (176439, 'locality-aware partitioning in parallel database systems.')]},
#  18025: {'name': 'v. m. megler',
#   'publications': [(175358,
#     'demonstrating "data near here": scientific data search.')]},
#  16393: {'name': 'david maier 0001',
#   'publications': [(175358,
#     'demonstrating "data near here": scientific data search.')]},
#  109393: {'name': 'yinan li',
#   'publications': [(175366,
#     'a padded encoding scheme to accelerate scans by leveraging skew.'),
#    (869721, 'fd-buffer: a buffer manager for databases on flash disks.')]},
#  271875: {'name': 'craig chasseur',
#   'publications': [(175366,
#     'a padded encoding scheme to accelerate scans by leveraging skew.')]},
#  14473: {'name': 'lu chen',
#   'publications': [(175367,
#     'indexing metric uncertain data for range queries.')]},
#  16180: {'name': 'yunjun gao',
#   'publications': [(175367,
#     'indexing metric uncertain data for range queries.'),
#    (175642,
#     'getreal: towards realistic selection of influence maximization strategies in competitive networks.')]},
#  16181: {'name': 'xinhan li',
#   'publications': [(175367,
# ...
#  365019: {'name': 'jonathan l. elsas',
#   'publications': [(253943,
#     'leveraging temporal dynamics of document content in relevance ranking.'),
#    (871129,
#     'rank learning for factoid question answering with linguistic and semantic constraints.')]},
#  115394: {'name': 'viet ha-thuc',
#   'publications': [(253945,
#     'large-scale hierarchical text classification without labelled data.'),
#    (658491, 'instant search: a hands-on tutorial.'),
#    (659380,
#     'learning to rank personalized search results in professional networks.')]},
#  14856: {'name': 'jean-michel renders',
#   'publications': [(253945,
#     'large-scale hierarchical text classification without labelled data.')]},
#  15950: {'name': 'christos faloutsos',
#   'publications': [(253949,
#     'mining billion-node graphs: patterns, generators and tools.'),
#    (427502,
#     'winner takes all: competing viruses or ideas on fair-play networks.'),
#    (638325,
#     'good-enough brain model: challenges, algorithms and discoveries in multi-subject experiments.'),
#    (638570,
#     'catchsync: catching synchronized behavior in large directed graphs.'),
#    (639294,
#     'detecting anomalies in dynamic rating data: a robust probabilistic model for rating evolution.'),
#    (639396, 'funnel: automatic mining of spatially coevolving epidemics.')]},
#  365028: {'name': 'harry shum',
#   'publications': [(253951,
#     'bing dialog model: intent, knowledge and user interaction.')]},
#  138871: {'name': 'daniel j. liebling',
#   'publications': [(253954,
#     'understanding and predicting personal navigation.')]},
#  365029: {'name': 'gayathri ravichandran geetha',
#   'publications': [(253954,
#     'understanding and predicting personal navigation.')]},
#  21391: {'name': 'steffen rendle',
#   'publications': [(253955,
#     'pairwise interaction tensor factorization for personalized tag recommendation.')]},
#  1170: {'name': 'lars schmidt-thieme',
#   'publications': [(253955,
#     'pairwise interaction tensor factorization for personalized tag recommendation.'),
#    (382436, 'sequential model-free hyperparameter tuning.'),
#    (639127, 'learning time-series shapelets.')]},
#  21197: {'name': 'dongyeop kang',
#   'publications': [(253960,
#     'multidimensional mining of large-scale search logs: a topic-concept cube approach.')]},
#  114431: {'name': 'daxin jiang',
#   'publications': [(253960,
#     'multidimensional mining of large-scale search logs: a topic-concept cube approach.')]},
#  365032: {'name': 'zhen liao',
#   'publications': [(253960,
#     'multidimensional mining of large-scale search logs: a topic-concept cube approach.'),
#    (428063, 'evaluating the effectiveness of search task trails.')]},
#  36607: {'name': 'xiaohui sun',
#   'publications': [(253960,
#     'multidimensional mining of large-scale search logs: a topic-concept cube approach.')]},
#  29219: {'name': 'ho-jin choi',
#   'publications': [(253960,
#     'multidimensional mining of large-scale search logs: a topic-concept cube approach.')]},
#  225947: {'name': 'silvio lattanzi',
#   'publications': [(253979, 'an algorithmic treatment of strong queries.'),
#    (544338, 'learning entangled single-sample gaussians.'),
#    (731279, 'community detection on evolving graphs.')]},
#  365042: {'name': 'jianshu weng',
#   'publications': [(253985,
#     'twitterrank: finding topic-sensitive influential twitterers.'),
#    (870459, 'mining interesting link formation rules in social networks.')]},
#  15806: {'name': 'ee-peng lim',
#   'publications': [(253985,
#     'twitterrank: finding topic-sensitive influential twitterers.'),
#    (342907,
#     'on unravelling opinions of issue specific-silent users in social media.'),
#    (383862,
#     'cnl: collective network linkage across heterogeneous social platforms.'),
#    (868541, 'finding unusual review patterns using unexpected rules.'),
#    (870377, 'detecting product review spammers using rating behaviors.'),
#    (870459, 'mining interesting link formation rules in social networks.')]},
#  15805: {'name': 'jing jiang',
#   'publications': [(253985,
#     'twitterrank: finding topic-sensitive influential twitterers.'),
#    (638898,
#     'jointly modeling aspects, ratings and sentiments for movie recommendation (jmars).'),
#    (869077,
#     'context modeling for ranking and tagging bursty features in text streams.')]},
#  364951: {'name': 'nadav golbandi',
#   'publications': [(253986,
#     'adaptive bootstrapping of recommender systems using decision trees.'),
#    (870665, 'on bootstrapping recommender systems.')]},
#  9202: {'name': 'yehuda koren',
#   'publications': [(253986,
#     'adaptive bootstrapping of recommender systems using decision trees.'),
#    (425270,
#     'build your own music recommender by modeling internet radio streams.'),
#    (427101,
#     'care to comment?: recommendations for commenting on news stories.'),
#    (870665, 'on bootstrapping recommender systems.')]},
#  20109: {'name': 'ronny lempel',
#   'publications': [(253986,
#     'adaptive bootstrapping of recommender systems using decision trees.'),
#    (425466, 'lightweight automatic face annotation in media pages.'),
#    (427101,
#     'care to comment?: recommendations for commenting on news stories.'),
#    (870665, 'on bootstrapping recommender systems.')]},
#  364811: {'name': 'claudio lucchese',
#   'publications': [(253988,
#     'identifying task-based sessions in search engine query logs.')]},
#  16323: {'name': 'salvatore orlando 0001',
#   'publications': [(253988,
#     'identifying task-based sessions in search engine query logs.')]},
#  365043: {'name': 'raffaele perego',
#   'publications': [(253988,
#     'identifying task-based sessions in search engine query logs.'),
#    (658247,
#     'post-learning optimization of tree ensembles for efficient ranking.'),
#    (658661,
#     'the comewithme system for searching and ranking activity-based carpooling rides.'),
#    (659059, 'polarized user and topic tracking in twitter.'),
#    (659114,
#     'exploiting cpu simd extensions to speed-up document scoring with tree ensembles.')]},
#  19211: {'name': 'fabrizio silvestri',
#   'publications': [(253988,
#     'identifying task-based sessions in search engine query logs.'),
#    (342691,
#     'on the behaviour of deviant communities in online social networks.'),
#    (425764,
#     'large-scale contextual query-to-ad matching and retrieval system for sponsored search: (abstract).'),
#    (658247,
#     'post-learning optimization of tree ensembles for efficient ranking.'),
#    (658645, 'network-aware recommendations of novel tweets.'),
#    (659765,
#     'scalable semantic matching of queries to ads in sponsored search advertising.'),
#    (868125,
#     'vsencoding: efficient coding and fast decoding of integer lists via dynamic programming.')]},
#  19210: {'name': 'gabriele tolomei',
#   'publications': [(253988,
#     'identifying task-based sessions in search engine query logs.')]},
#  364913: {'name': 'georges dupret',
#   'publications': [(253989,
#     'a model to estimate intrinsic document relevance from the clickthrough logs of a web search engine.'),
#    (869834, 'user behavior driven ranking without editorial judgments.')]},
#  273515: {'name': 'zeyuan allen zhu',
#   'publications': [(253992,
#     'a novel click model and its applications to online advertising.'),
#    (354350, 'mechanism design with approximate valuations.'),
#    (544978, 'flow-based algorithms for local graph clustering.'),
#    (731496, 'even faster svd decomposition yet without agonizing pain.'),
#    (732703,
#     'exploiting the structure: stochastic gradient methods using raw clusters.'),
#    (732904, 'optimal black-box reductions between optimization objectives.')]},
#  364843: {'name': 'weizhu chen',
#   'publications': [(253992,
#     'a novel click model and its applications to online advertising.'),
#    (254199,
#     'action prediction and identification from mining temporal user behaviors.'),
#    (870276, 'learning click models via probit bayesian inference.'),
#    (870467, 'explore click models for search ranking.')]},
#  48845: {'name': 'tom minka',
#   'publications': [(253992,
#     'a novel click model and its applications to online advertising.')]},
#  365044: {'name': 'chenguang zhu',
#   'publications': [(253992,
#     'a novel click model and its applications to online advertising.')]},
#  9631: {'name': 'zheng chen',
#   'publications': [(253992,
#     'a novel click model and its applications to online advertising.'),
#    (254077,
#     'cross lingual text classification by mining multilingual topics from wikipedia.')]},
#  365046: {'name': 'bilyana taneva',
#   'publications': [(253994,
#     'gathering and ranking photos of named entities with high precision, high recall, and diversity.')]},
#  29494: {'name': 'mouna kacimi',
#   'publications': [(253994,
#     'gathering and ranking photos of named entities with high precision, high recall, and diversity.')]},
#  17528: {'name': 'gerhard weikum',
#   'publications': [(253994,
#     'gathering and ranking photos of named entities with high precision, high recall, and diversity.'),
#    (254230,
#     'scalable knowledge harvesting with high precision and high recall.'),
#    (383996,
#     'experience-aware item recommendation in evolving review communities.'),
#    (425443,
#     'lights, camera, action: knowledge extraction from movie scripts.'),
#    (425647,
#     'aligning multi-cultural knowledge taxonomies by combinatorial optimization.'),
#    (426062, 'knowledge bases for web content analytics.'),
#    (639155,
#     'people on drugs: credibility of user statements in health communities.'),
#    (658422,
#     'r-susceptibility: an ir-centric approach to assessing privacy risks for users in online communities.'),
#    (659676,
#     'context-sensitive auto-completion for searching with entities and categories.'),
#    (868257, 'fast and accurate estimation of shortest paths in large graphs.'),
#    (869188, 'menta: inducing multilingual taxonomies from wikipedia.'),
#    (871227,
#     'incorporating terminology evolution for query translation in text retrieval with association rules.')]},
#  161596: {'name': 'pengcheng wu',
#   'publications': [(253996,
#     'mining social images with distance metric learning for automated image tagging.')]},
#  8632: {'name': 'steven c. h. hoi',
#   'publications': [(253996,
#     'mining social images with distance metric learning for automated image tagging.'),
#    (254137, 'a two-view learning approach for image tag ranking.'),
#    (384019,
#     'cost-sensitive online classification with adaptive regularization and its applications.'),
#    (639951, 'online multiple kernel regression.'),
#    (658150,
#     'on effective personalized music retrieval by exploring online user behaviors.')]},
#  9450: {'name': 'peilin zhao',
#   'publications': [(253996,
#     'mining social images with distance metric learning for automated image tagging.'),
#    (382476,
#     'an aggressive graph-based selective sampling algorithm for classification.'),
#    (382581, 'sparse online relative similarity learning.'),
#    (384019,
#     'cost-sensitive online classification with adaptive regularization and its applications.')]},
#  28279: {'name': 'ying he 0001',
#   'publications': [(253996,
#     'mining social images with distance metric learning for automated image tagging.')]},
#  272644: {'name': 'lilyana mihalkova',
#   'publications': [(254005,
#     'exploiting statistical and relational information on the web and in social media.')]},
#  365052: {'name': 'steven minton',
#   'publications': [(254008,
#     'materializing multi-relational databases from the web using taxonomic queries.')]},
#  21324: {'name': 'berkant barla cambazoglu',
#   'publications': [(254014,
#     'document assignment in multi-site search engines.'),
#    (254250,
#     'early exit optimizations for additive machine learned ranking systems.'),
#    (426431,
#     'propagating expiration decisions in a search engine result cache.'),
#    (658159,
#     'improved caching techniques for large-scale image hosting services.'),
#    (659110,
#     'scalability and efficiency challenges in large-scale web search engines.'),
#    (870012, 'web search solved?: all result rankings the same?')]},
#  216243: {'name': 'flavio paiva junqueira',
#   'publications': [(254014,
#     'document assignment in multi-site search engines.')]},
#  18165: {'name': 'george papadakis 0001',
#   'publications': [(254017,
#     'efficient entity resolution for large heterogeneous information spaces.')]},
#  272290: {'name': 'ekaterini ioannou',
#   'publications': [(254017,
#     'efficient entity resolution for large heterogeneous information spaces.')]},
#  265702: {'name': 'claudia nieder&eacute;e',
#   'publications': [(254017,
#     'efficient entity resolution for large heterogeneous information spaces.'),
#    (425429, 'mining relevant time for query subtopics in web archives.'),
#    (427335,
#     'time-travel translator: automatically contextualizing news articles.')]},
#  150759: {'name': 'peter fankhauser',
#   'publications': [(254017,
#     'efficient entity resolution for large heterogeneous information spaces.'),
#    (254120, 'boilerplate detection using shallow text features.')]},
#  365059: {'name': 'michael j. welch',
#   'publications': [(254025, 'topical semantics of twitter links.'),
#    (869202, 'generating advertising keywords from video content.')]},
#  365060: {'name': 'uri schonfeld',
#   'publications': [(254025, 'topical semantics of twitter links.')]},
#  53160: {'name': 'dan he',
#   'publications': [(254025, 'topical semantics of twitter links.')]},
#  18369: {'name': 'junghoo cho',
#   'publications': [(254025, 'topical semantics of twitter links.'),
#    (639698,
#     'who are experts specializing in landscape photography?: analyzing topic-specific authority on content sharing services.'),
#    (869202, 'generating advertising keywords from video content.')]},
#  300861: {'name': 'ou wu',
#   'publications': [(254026,
#     'evaluating the visual quality of web pages using a computational aesthetic approach.'),
#    (870918, 'group ranking with application to image retrieval.')]},
#  20986: {'name': 'yunfei chen',
#   'publications': [(254026,
#     'evaluating the visual quality of web pages using a computational aesthetic approach.')]},
#  161707: {'name': 'bing li 0001',
#   'publications': [(254026,
#     'evaluating the visual quality of web pages using a computational aesthetic approach.'),
#    (870918, 'group ranking with application to image retrieval.')]},
#  162108: {'name': 'weiming hu',
#   'publications': [(254026,
#     'evaluating the visual quality of web pages using a computational aesthetic approach.'),
#    (870918, 'group ranking with application to image retrieval.')]},
#  255911: {'name': 'flavio figueiredo',
#   'publications': [(254036,
#     'the tube over time: characterizing popularity growth of youtube videos.')]},
#  179615: {'name': 'fabr&iacute;cio benevenuto',
#   'publications': [(254036,
#     'the tube over time: characterizing popularity growth of youtube videos.'),
#    (342679,
#     'fusing audio, textual, and visual features for sentiment analysis of news videos.'),
#    (342780, 'analyzing the targets of hate in online social media.'),
#    (342886,
#     'ifeel 2.0: a multilingual benchmarking system for sentence-level sentiment analysis.'),
#    (427519,
#     'understanding and combating link farming in the twitter social network.')]},
#  15049: {'name': 'jussara m. almeida',
#   'publications': [(254036,
#     'the tube over time: characterizing popularity growth of youtube videos.')]},
#  364839: {'name': 'lars backstrom',
#   'publications': [(254038,
#     'supervised random walks: predicting and recommending links in social networks.')]},
#  365065: {'name': 'amit goyal 0002',
#   'publications': [(254040,
#     'learning influence probabilities in social networks.')]},
#  364934: {'name': 'samuel ieong',
#   'publications': [(254043, 'optimizing merchant revenue with rebates.')]},
#  79993: {'name': 'raja velu',
#   'publications': [(254043, 'optimizing merchant revenue with rebates.')]},
#  365066: {'name': 'eric crestan',
#   'publications': [(254044, 'web-scale table census and classification.'),
#    (869060, 'a fine-grained taxonomy of tables on the web.')]},
#  ...}

# %% [markdown]
# Now,
#
#     for each couple of authors:
#         if they are linked:
#             evaluate the Jaccard distance
#             set it as weigth for the edge

# %%
#code
def jaccard_dist (id_1, id_2, inv_dict):
    publ_1 = set([inverted_dictionary[id_1]['publications'][i][0] for i in range(len(inverted_dictionary[id_1]['publications']))])
    publ_2 = set([inverted_dictionary[id_2]['publications'][i][0] for i in range(len(inverted_dictionary[id_2]['publications']))])
    union  = publ_1.union(publ_2)
    intersection = publ_1.intersection(publ_2)
    return 1-len(intersection)/len(union)

# %%
#let's add weigths to the graphs
for author1 in inverted_dictionary:
    for author2 in Authors.neighbors(author1):
        Authors[author1][author2]['weight'] = jaccard_dist(author1, author2, inverted_dictionary)

# %% [markdown]
# # ho qualche problema..

# %%
nx.info(Authors) #edges adriano : 16689
# Out:
# 'Name: Authors Graph\nType: Graph\nNumber of nodes: 7771\nNumber of edges: 16488\nAverage degree:   4.2435'

# %% [markdown]
# ## Given a conference in input, return the subgraph induced by the set of authors who published at the input conference at least once
#
# given the list of nodes of the subgraph
#
#     nbunch
#
# we can make the induced subgraph as follows:
#
#     Graph.subgraph(nbunch)
#
# Return the subgraph induced on nodes in nbunch. The induced subgraph of the graph conOtains the nodes in nbunch and the edges between those nodes.. For **example**
#
#     >>> G = nx.Graph()   # or DiGraph, MultiGraph, MultiDiGraph, etc
#     >>> G.add_path([0,1,2,3])
#     >>> H = G.subgraph([0,1,2])
#     >>> H.edges()
#     [(0, 1), (1, 2)]

# %%
pubDict = {}
#in questo dizionario la chiave è la publication id
#i valori sono gli autori
for i in range(len(data)):
    for a in data[i]['authors']:
        for j in range(len(data[i]['authors'])):
            key = data[i]['id_conference_int']
            if key in pubDict.keys():
                if data[i]['authors'][j]['author_id'] not in pubDict[key]:
                    pubDict[key].append(data[i]['authors'][j]['author_id'])
            else:
                pubDict[key] = [data[i]['authors'][j]['author_id']]

# %%
#inserire in input la pubblicazione
confInt = int(input())
#nbunch will be the list of author's id that contribuited to tha
nbunch = pubDict[confInt]
Sottografo = Authors.subgraph(nbunch)
Sottografo.name = 'Contributors to '+ str(confInt) + ' conference'
nx.info(Sottografo)
#175152
#161584
#3345
# Out:
# 3345
# 'Name: Contributors to 3345 conference\nType: Graph\nNumber of nodes: 622\nNumber of edges: 1659\nAverage degree:   5.3344'

# %%
import matplotlib.pyplot as plt
plt.clf()
nx.draw(Sottografo)
plt.show()
# Out:
# /home/mattiapdo/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /home/mattiapdo/anaconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /home/mattiapdo/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# /home/mattiapdo/anaconda3/lib/python3.6/site-packages/matplotlib/rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")

# %%
degree_centrality = nx.degree_centrality(Sottografo)
closeness_centrality = nx.closeness_centrality(Sottografo)
betweeness_centrality = nx.betweenness_centrality(Sottografo)

# %% [markdown]
# We can now update the graph by adding the centrality measure as label of the nodes.

# %%
degrees =list(degree_centrality.values())
centralities = list(closeness_centrality.values())
betweennesses = list(betweeness_centrality.values())

# %%
plt.clf()
plt.figure()
plt.hist(degrees, bins=30, color='red', histtype='step')
plt.title('Degree centrality')
plt.xlabel('degree centrality')
plt.ylabel('count')
plt.xlim()
plt.show()

plt.clf()
plt.figure()
plt.hist(degrees, bins=30, color='blue', histtype='step')
plt.title('Closeness centrality')
plt.xlabel('closeness centrality')
plt.ylabel('count')
plt.show()

plt.clf()
plt.figure()
plt.hist(degrees, bins=30, color='green', histtype='step')
plt.title('Betweenness centrality')
plt.xlabel('betweennes centrality')
plt.ylabel('count')
plt.show()
